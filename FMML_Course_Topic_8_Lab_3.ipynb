# %% [markdown]
# <a href="https://colab.research.google.com/github/Pallavibandreddy/FMML-Module-5-Project/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-30 17:46:53--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   152MB/s    in 0.5s
#
# 2024-03-30 17:46:54 (152 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 2405   1604.07928v2  Tensor factorization is a powerful tool to ana...    cs
# 38532   0912.0607v1  In this paper, a new reversible image authenti...    cs
# 7983   1706.09555v1  We propose a novel neural network model for mu...    cs
# 37749  1802.09100v1  Poor nutrition can lead to reduced immunity, i...    cs
# 4298   1801.03523v1  The present paper aims to demonstrate the usag...  stat
# ...             ...                                                ...   ...
# 11758  1611.05780v4  In high dimensional regression settings, spars...  stat
# 10618  1604.03006v2  Estimating mutual information from i.i.d. samp...    cs
# 7209   1711.01297v1  We interpret HyperNetworks within the framewor...  stat
# 8965   1712.05191v1  With the advent of the Internet, large amount ...    cs
# 7348   1712.00028v1  The gap between our ability to collect interes...    cs
#
#                                                    title  year  \
# 2405   Distributed Flexible Nonlinear Tensor Factoriz...  2016
# 38532  Reversible Image Authentication with Tamper Lo...  2009
# 7983   Music Signal Processing Using Vector Product N...  2017
# 37749  Can a Chatbot Determine My Diet?: Addressing C...  2018
# 4298   Generative Models for Stochastic Processes Usi...  2018
# ...                                                  ...   ...
# 11758  Gap Safe screening rules for sparsity enforcin...  2016
# 10618  Demystifying Fixed k-Nearest Neighbor Informat...  2016
# 7209      Implicit Weight Uncertainty in Neural Networks  2017
# 8965                      Relation Extraction : A Survey  2017
# 7348   Feature discovery and visualization of robot m...  2017
#
#                                                 keywords
# 2405   [factorization, traditional, nonlinear, factor...
# 38532  [reversible, authentication, technique, locali...
# 7983   [processing, dimensionality, transformations, ...
# 37749  [nutrition, increased, susceptibility, develop...
# 4298   [demonstrate, convolutional, generative, stoch...
# ...                                                  ...
# 11758  [dimensional, regression, enforcing, penalties...
# 10618  [estimating, information, statistical, multitu...
# 7209   [interpret, hypernetworks, framework, variatio...
# 8965   [generated, publications, answering, important...
# 7348   [interesting, unprecedented, algorithmic, unsu...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 2405     [factorization, traditional, nonlinear, factor...
# 38532    [reversible, authentication, technique, locali...
# 7983     [processing, dimensionality, transformations, ...
# 37749    [nutrition, increased, susceptibility, develop...
# 4298     [demonstrate, convolutional, generative, stoch...
#                                ...
# 24349    [compressive, efficient, reconstruction, measu...
# 7812     [specifically, convolutional, structured, neig...
# 18742    [theoretical, transition, production, bipartit...
# 30769    [multimodal, multimedia, aesthetically, intuit...
# 28613    [importance, coordination, activities, detecti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8742 words.
# Out of those 4564 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c51b9ce7-23c7-49df-8114-4ee055d050ae" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c51b9ce7-23c7-49df-8114-4ee055d050ae")) {                    Plotly.newPlot(                        "c51b9ce7-23c7-49df-8114-4ee055d050ae",                        [{"x":["potential","factorization","capturing","experimental","demonstrate","computationally","distributed","promising","kronecker","nonlinear","advantages","effectively","decoupled","structural","prediction","advertising","predictive","application","arbitrary","relationships","mechanism","tensorial","inference","formulations","variational","tractable","algorithm","expensive","framework","efficiency","contribute","limitations","computational","restrictions","performance","computations","traditional","mapreduce","approaches","authenticity","characteristics","embedding","completely","tampering","coefficients","watermarking","positions","localized","difference","watermark","modifications","distortion","reversible","histogram","authentication","watermarked","transform","technique","selective","localization","dimensionality","dimensional","separation","transformations","transformation","processing","background","technical","behavioural","development","productivity","addressing","conversational","determine","motivation","developers","susceptibility","technically","theoretically","challenges","theoretical","describes","implement","increased","associated","guidelines","recommendation","processes","simulations","parameters","generative","researchers","quantitative","structure","forecasts","convolutional","stochastic","conditional","regression","optimizers","surrogate","exchangeable","addresses","approximating","benchmark","functions","objective","scenarios","continuous","comparing","optimization","comprehensive","parallelization","including","categorical","visualization","implemented","empirically","different","additional","components","complexity","environment","deployment","demonstrations","observable","interaction","pedestrians","partially","simulation","interactions","integration","curvatures","recurrent","reinforcement","applications","relatively","difficult","motivated","particular","attention","integrates","simulator","considered","relevance","incorporates","information","successfully","autonomous","successful","perceived","supervised","automotive","competing","competitors","estimates","experiments","frequentist","leverages","uncertainty","automatic","hyperparameter","reconstruction","generating","translation","evaluation","generated","containing","newspaper","movements","segmentations","adversarial","synthesize","reconstructing","operations","inspection","observers","exploring","generation","segmentation","realistic","substructures","representation","constructed","hierarchies","hierarchical","theoretic","algorithms","additionally","vocabularies","properties","vocabulary","selection","description","compressing","descriptive","discovery","architecture","clustering","hierarchy"],"y":[176,34,41,358,533,87,104,115,4,60,98,130,8,86,250,7,50,260,90,71,111,2,223,15,48,31,780,57,551,172,27,61,287,17,898,37,149,5,452,4,83,106,40,3,42,4,25,21,60,2,19,33,5,23,8,3,65,249,18,66,51,165,24,36,54,273,77,41,7,115,2,13,17,72,15,10,2,3,48,100,149,90,65,47,102,13,31,124,49,231,116,73,72,340,4,383,142,114,132,5,13,3,56,18,247,210,155,97,110,71,338,54,5,250,10,32,104,85,751,110,104,216,131,15,9,13,72,13,40,92,71,47,0,141,123,414,62,144,59,266,168,23,9,125,27,31,695,80,56,67,18,203,2,29,8,75,629,0,32,78,180,10,96,99,114,278,166,62,6,11,14,101,18,14,70,8,10,48,137,199,73,4,371,52,18,96,62,573,60,7,213,28,150,66,5,20,55,227,116,36],"type":"bar"},{"x":["potential","factorization","capturing","experimen ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4564,), (4564, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>struc2vec</span> <span style=''>Learning</span> <span style=''>Node</span> <span style='background-color:rgba(0, 255, 0, 0.3882352941176471);'>Representations</span> <span style=''>from</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>Identity</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>identity</span> <span style=''>is</span> <span style=''>a</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>symmetry</span> <span style=''>in</span> <span style=''>which</span> <span style=''>network</span> <span style=''>nodes</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>identified</span> <span style='background-color:rgba(0, 255, 0, 0.49275362318840576);'>according</span> <span style=''>to</span> <span style=''>the</span> <span style=''>network</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>and</span> <span style=''>their</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relationship</span> <span style=''>to</span> <span style=''>other</span> <span style=''>nodes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structural</span> <span style=''>identity</span> <span style=''>has</span> <span style=''>been</span> <span style=''>studied</span> <span style=''>in</span> <span style=''>theory</span> <span style=''>and</span> <span style=''>practice</span> <span style=''>over</span> <span style=''>the</span> <span style=''>past</span> <span style=''>decades</span> <span style=''>but</span> <span style=''>only</span> <span style=''>recently</span> <span style=''>has</span> <span style=''>it</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3823529411764705);'>addressed</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.5999999999999999);'>representational</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>techniques</span> <span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>struc2vec</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>and</span> <span style=''>flexible</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>learning</span> <span style=''>latent</span> <span style='background-color:rgba(0, 255, 0, 0.3882352941176471);'>representations</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>identity</span> <span style=''>of</span> <span style=''>nodes</span> <span style=''>struc2vec</span> <span style=''>uses</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.38461538461538464);'>hierarchy</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>node</span> <span style='background-color:rgba(0, 255, 0, 0.3721973094170404);'>similarity</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.338680926916221);'>different</span> <span style=''>scales</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3513513513513513);'>constructs</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>multilayer</span> <span style=''>graph</span> <span style=''>to</span> <span style=''>encode</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style=''>generate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structural</span> <span style=''>context</span> <span style=''>for</span> <span style=''>nodes</span> <span style='background-color:rgba(255, 0, 0, 0.4651162790697674);'>Numerical</span> <span style='background-color:r ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Differentially</span> <span style=''>Private</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>fine</span> <span style=''>tuning</span> <span style=''>the</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>models</span> <span style=''>The</span> <span style=''>success</span> <span style=''>of</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>has</span> <span style=''>led</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practitioners</span> <span style=''>in</span> <span style=''>diverse</span> <span style=''>real</span> <span style=''>world</span> <span style=''>settings</span> <span style=''>to</span> <span style=''>learn</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>problems</span> <span style=''>As</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>becomes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>commonplace</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>becomes</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>attractive</span> <span style=''>method</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practitioners</span> <span style=''>to</span> <span style=''>automate</span> <span style=''>the</span> <span style=''>process</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifier</span> <span style=''>hyper</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <span style=''>A</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>observation</span> <span style=''>is</span> <span style=''>that</span> <span style=''>the</span> <span style=''>data</span> <span style=''>used</span> <span style=''>for</span> <span style=''>tuning</span> <span style=''>models</span> <span style=''>in</span> <span style=''>these</span> <span style=''>settings</span> <span style=''>is</span> <span style=''>often</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sensitive</span> <span style=''>Certain</span> <span style=''>data</span> <span style=''>such</span> <span style=''>as</span> <span style=''>genetic</span> <span style=''>predisposition</span> <span style=''>personal</span> <span style=''>email</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>and</span> <span style=''>car</span> <span style=''>accident</span> <span style=''>history</span> <span style=''>if</span> <span style=''>not</span> <span style=''>properly</span> <span style=''>private</span> <span style=''>may</span> <span style=''>be</span> <span style=''>at</span> <span style=''>risk</span> <span style=''>of</span> <span style=''>being</span> <span style=''>inferred</span> <span style=''>from</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>outputs</span> <span style=''>To</span> <span style=''>address</span> <span style=''>this</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3441295546558705);'>Regularization</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4253308128544424);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distribution</span> <span style=''>over</span> <span style=''>the</span> <span style=''>data</span> <span style=''>points</span> <span style=''>(unlabeled</span> <span style=''>data)</span> <span style=''>The</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>principle</span> <span style=''>is</span> <span style=''>cast</span> <span style=''>in</span> <span style=''>terms</span> <span style=''>of</span> <span style=''>Tikhonov</span> <span style=''>style</span> <span style='background-color:rgba(255, 0, 0, 0.3441295546558705);'>regularization</span> <span style=''>where</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3441295546558705);'>regularization</span> <span style=''>penalty</span> <span style=''>articulates</span> <span style=''>the</span> <span style=''>way</span> <span style=''>in</span> <span style=''>which</span> <span style=''>the</span> <span style=''>marginal</span> <span style=''>density</span> <span style=''>should</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>constrain</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>otherwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrestricted</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3441295546558705);'>regularization</span> <span style=''>penalty</span> <span style='background-color:rgba(255, 0, 0, 0.5000000000000001);'>penalizes</span> <span style=''>any</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduced</span> <span style=''>between</span> <span style=''>the</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>labels</span> <span style=''>beyond</span> <span style=''>what</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>available</span> <span style=''>labeled</span> <span style=''>examples</span> <span style=''>The</span> <span style=''>work</span> <span style=''>extends</span> <span style=''>Szummer</span> <span style=''>and</span> <span style=''>Jaakkolas</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3441295546558705);'>regularization</span> <span style=''>(NIPS</span> <span style=''>2002)</span> <span style=''>to</span> <span style=''>multiple</span> <span style='background-color:rgba(255, 0, 0, 0.4513274336283186);'>dimensions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>independent</span> <span style=''>of</span> <span style=''>the</span> <span style=''>covering</span> <span style=''>of</span> <span style=''>the</span> <span style=''>space</span> <span style=''>used</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Ground</span> <span style=''>Metric</span> <span style=''>Learning</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Transportation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>have</span> <span style=''>been</span> <span style=''>used</span> <span style=''>for</span> <span style=''>more</span> <span style=''>than</span> <span style=''>a</span> <span style=''>decade</span> <span style=''>now</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>to</span> <span style=''>compare</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>histograms</span> <span style=''>of</span> <span style=''>features</span> <span style=''>They</span> <span style=''>have</span> <span style=''>one</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>the</span> <span style=''>ground</span> <span style=''>metric</span> <span style=''>which</span> <span style=''>can</span> <span style=''>be</span> <span style=''>any</span> <span style=''>metric</span> <span style=''>between</span> <span style=''>the</span> <span style=''>features</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>themselves</span> <span style=''>As</span> <span style=''>is</span> <span style=''>the</span> <span style=''>case</span> <span style=''>for</span> <span style=''>all</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameterized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transportation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>can</span> <span style=''>only</span> <span style=''>prove</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>practice</span> <span style=''>when</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>carefully</span> <span style=''>chosen</span> <span style=''>To</span> <span style=''>date</span> <span style=''>the</span> <span style=''>only</span> <span style=''>option</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>available</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practitioners</span> <span style=''>to</span> <span style=''>set</span> <span style=''>the</span> <span style=''>ground</span> <span style=''>metric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>was</span> <span style=''>to</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>a</span> <span style=''>priori</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>features</span> <span style=''>which</span> <span style=''>limited</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>considerably</span> <span style=''>the</span> <span style=''>scope</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>transportation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distances</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>lift</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>limitation</span> <span style=''>and</span> <span style=''>consider</span> <span style=''>instead</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>can</span> <span style=''>learn</span> <span style=''>the</span> <span style=''>ground</span> <span style=''>metric</span> <span style=''>using</span> <span style=''>only</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.081216457960644)
# 	evaluation (0.09946332737030411)
# 	representation (0.13273703041144902)
# 	segmentation (0.07119856887298748)
# 	information (0.24865831842576028)
# 	knowledge (0.13488372093023257)
# 	detection (0.11627906976744186)
# 	different (0.26869409660107335)
# 	recognition (0.13416815742397137)
# 	convolutional (0.1370304114490161)
#
# Some Statistics words are:
# 	variational (0.10124688279301745)
# 	theoretical (0.14463840399002495)
# 	variables (0.142643391521197)
# 	statistical (0.15261845386533665)
# 	estimation (0.16658354114713217)
# 	algorithm (0.3790523690773067)
# 	distribution (0.18304239401496258)
# 	inference (0.19950124688279303)
# 	dimensional (0.18802992518703243)
# 	regression (0.19201995012468828)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f0d70e82-cdc9-467c-bb94-26292f23d009" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f0d70e82-cdc9-467c-bb94-26292f23d009")) {                    Plotly.newPlot(                        "f0d70e82-cdc9-467c-bb94-26292f23d009",                        [{"x":["potential","factorization","capturing","experimental","demonstrate","computationally","distributed","promising","kronecker","nonlinear","advantages","effectively","decoupled","structural","prediction","advertising","predictive","application","arbitrary","relationships","mechanism","tensorial","inference","formulations","variational","tractable","algorithm","expensive","framework","efficiency","contribute","limitations","computational","restrictions","performance","computations","traditional","mapreduce","approaches","authenticity","characteristics","embedding","completely","tampering","coefficients","watermarking","positions","localized","difference","watermark","modifications","distortion","reversible","histogram","authentication","watermarked","transform","technique","selective","localization","dimensionality","dimensional","separation","transformations","transformation","processing","background","technical","behavioural","development","productivity","addressing","conversational","determine","motivation","developers","susceptibility","technically","theoretically","challenges","theoretical","describes","implement","increased","associated","guidelines","recommendation","processes","simulations","parameters","generative","researchers","quantitative","structure","forecasts","convolutional","stochastic","conditional","regression","optimizers","surrogate","exchangeable","addresses","approximating","benchmark","functions","objective","scenarios","continuous","comparing","optimization","comprehensive","parallelization","including","categorical","visualization","implemented","empirically","different","additional","components","complexity","environment","deployment","demonstrations","observable","interaction","pedestrians","partially","simulation","interactions","integration","curvatures","recurrent","reinforcement","applications","relatively","difficult","motivated","particular","attention","integrates","simulator","considered","relevance","incorporates","information","successfully","autonomous","successful","perceived","supervised","automotive","competing","competitors","estimates","experiments","frequentist","leverages","uncertainty","automatic","hyperparameter","reconstruction","generating","translation","evaluation","generated","containing","newspaper","movements","segmentations","adversarial","synthesize","reconstructing","operations","inspection","observers","exploring","generation","segmentation","realistic","substructures","representation","constructed","hierarchies","hierarchical","theoretic","algorithms","additionally","vocabularies","properties","vocabulary","selection","description","compressing","descriptive","discovery","architecture","clustering","hierarchy","statistical","compositional","compositions","principle","performed","retrieval","discovered","mechanisms","unsupervised","reciprocal","identification","especially","calculated","solutions","applicable","effectiveness","community","hypothesis","considering","specifically","combination","neighbors","complement","infeasible","convergence","exploited","adaptively","important","constrained","parameter","according","simultaneously","competitiveness","constraint","complementary","diversity","populations","evolutionary","restricted","evolution","feasibility","appropriate","maintains","diversified","population","efficiently","combinatorial","prohibitive","targeting","extraction","triggered","empirical","efficient ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	curvatures
# 	frequentist
# 	metabolic
# 	safeguard
# 	consolidation
# 	cumulants
# 	gaussianization
# 	dendrogram
# 	nonparanormal
# 	subsamples
# 	distilling
# 	attributing
# 	inhomogeneity
# 	confounder
# 	dependences
# 	tractographies
# 	streamline
# 	prominently
# 	discriminants
# 	astronomical
# Some words which never appear in Statistics papers:
# 	authenticity
# 	tampering
# 	watermarking
# 	watermark
# 	authentication
# 	watermarked
# 	conversational
# 	susceptibility
# 	newspaper
# 	observers
# 	descriptive
# 	semantically
# 	interpretive
# 	evaluators
# 	keyphrases
# 	evidential
# 	positioning
# 	subjected
# 	depicting
# 	vietnamese

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.075598203850649e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7641666666666667
